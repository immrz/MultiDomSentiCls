# %%
import sys
sys.path.append('/home/v-runmao/projects/ATMF')

from analyze_bad_case import generate_bad_case, visualize

import transformers
transformers.logging.set_verbosity_error()

# %%
generate_bad_case('ERM', 'A')
# Out:
# ...
# Acc: 84.93%

# %%
generate_bad_case('DANN', 'A')
# Out:
# ...
# Acc: 85.42%

# %%
generate_bad_case('MLDG', 'A')
# Out:
# ...
# Acc: 84.62%

# %% [markdown]
# # Visualize ERM

# %%
n = 20
sort = False
max_len = 200

# %%
visualize('ERM', 'A', n=n, sort=sort, max_len=max_len)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>pos</b></text></td><td><text style="padding-right:2em"><b>neg (0.73)</b></text></td><td><text style="padding-right:2em"><b>NA</b></text></td><td><text style="padding-right:2em"><b>-
# ...

# %% [markdown]
# # Visualize DANN

# %%
visualize('DANN', 'A', n=n, sort=sort, max_len=max_len)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>pos</b></text></td><td><text style="padding-right:2em"><b>neg (0.52)</b></text></td><td><text style="padding-right:2em"><b>NA</b></text></td><td><text style="padding-right:2em"><b>-
# ...

# %% [markdown]
# # Visualize MLDG

# %%
visualize('MLDG', 'A', n=n, sort=sort, max_len=max_len)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>pos</b></text></td><td><text style="padding-right:2em"><b>neg (0.62)</b></text></td><td><text style="padding-right:2em"><b>NA</b></text></td><td><text style="padding-right:2em"><b>-
# ...
