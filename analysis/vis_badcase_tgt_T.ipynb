# %%
import sys
sys.path.append('/home/v-runmao/projects/ATMF')

from analyze_bad_case import generate_bad_case, visualize

import transformers
transformers.logging.set_verbosity_error()

# %%
generate_bad_case('ERM', 'T')
# Out:
# ...
# Acc: 80.56%

# %%
generate_bad_case('DANN', 'T')
# Out:
# ...
# Acc: 83.34%

# %%
generate_bad_case('MLDG', 'T')
# Out:
# ...
# Acc: 81.35%

# %% [markdown]
# # Visualize ERM

# %%
n = 20
sort = False

# %%
visualize('ERM', 'T', n=n, sort=sort)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>neg</b></text></td><td><text style="padding-right:2em"><b>pos (0.93)</b></text></td><td><text style="padding-right:2em"><b>NA</b></text></td><td><text style="padding-right:2em"><b>0
# ...

# %%
visualize('DANN', 'T', n=n, sort=sort)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>neg</b></text></td><td><text style="padding-right:2em"><b>pos (0.75)</b></text></td><td><text style="padding-right:2em"><b>NA</b></text></td><td><text style="padding-right:2em"><b>-
# ...

# %%
visualize('MLDG', 'T', n=n, sort=sort)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>neg</b></text></td><td><text style="padding-right:2em"><b>pos (0.89)</b></text></td><td><text style="padding-right:2em"><b>NA</b></text></td><td><text style="padding-right:2em"><b>-
# ...
